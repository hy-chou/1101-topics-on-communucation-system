# %%
from qiskit import *

# %%
circuit = QuantumCircuit(1, 1)
circuit.x(0)
circuit.measure([0], [0])
circuit.draw()

# %%
apitoken = 'b160db11fdb795104a74b47e28b19e195b424d8ea43659c25f6f824894716da7e4ef289ddf612c94d247fccdcf59cf2a03b6992c723adf6502d10bc2c01e92f7'
IBMQ.save_account(apitoken)
# Out:
# configrc.store_credentials:WARNING:2021-09-21 16:50:14,913: Credentials already present. Set overwrite=True to overwrite.

# %%
IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')
qcomp = provider.get_backend('ibmq_santiago')

# %%
job = execute(circuit, backend=qcomp, shots=1000)

# %%
from qiskit.tools.monitor import job_monitor
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %%
result = job.result()
counts = result.get_counts(circuit)

# %%
from qiskit.tools.visualization import plot_histogram
plot_histogram(counts)
